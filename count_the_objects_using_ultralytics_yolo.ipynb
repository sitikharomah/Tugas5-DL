# %% [markdown]
# <a href="https://colab.research.google.com/github/sitikharomah/Tugas5-DL/blob/main/count_the_objects_using_ultralytics_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/notebooks/blob/main/notebooks/how-to-count-the-objects-using-ultralytics-yolo.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
#   Welcome to the Object counting using Ultralytics YOLO11 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLO11</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. We hope that the resources in this notebook will help you get the most out of YOLO11. Please browse the YOLO11 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!</div>

# %% [markdown]
# # Object Counting using Ultralytics YOLO11
#
# This notebook serves as a starting point for [counting objects](https://docs.ultralytics.com/guides/object-counting/) in videos or live streams using the YOLO11 model.
#
# ### What is Object Counting?
#
# - Object counting with YOLO11 involves accurate identification and counting of specific objects in videos and camera streams. YOLO11 excels in real-time applications, providing efficient and precise object counting for various scenarios like crowd analysis and surveillance, thanks to its state-of-the-art algorithms and deep learning capabilities.
#
# ### Advantages of Object Counting?
#
# - **Resource Optimization**: Object counting facilitates efficient resource management by providing accurate counts, and optimizing resource allocation in applications like inventory management.
# - **Enhanced Security**: Object counting enhances security and surveillance by accurately tracking and counting entities, aiding in proactive threat detection.
# - **Informed Decision-Making**: Object counting offers valuable insights for decision-making, optimizing processes in retail, traffic management, and various other domains.

# %% [markdown]
# ### Setup
#
# pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# !pip install ultralytics

import ultralytics
import cv2
from ultralytics import solutions

ultralytics.checks()
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.3/112.6 GB disk)

# %% [markdown]
# ### Read the Video File
#
# - You can either read the video file directly or stream the content from an RTSP (Real-Time Streaming Protocol) source, allowing for flexible video input depending on your needs.
# - We will also set up the video writer to handle the output video writing.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="MKepO7ricrAslnCiFGEX")
project = rf.workspace("tugas4dl").project("praktik-object-detection")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.64-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.4.26)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.2.1)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.58.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)
# Downloading roboflow-1.1.64-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 9.0 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 27.5 MB/s eta 0:00:00
# Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 127.0 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: filetype, python-dotenv, pillow-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 python-dotenv-1.1.0 roboflow-1.1.64
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in praktik-object-detection-2 to yolov11:: 100%|██████████| 35034/35034 [00:03<00:00, 10047.12it/s]
# Extracting Dataset Version Zip to praktik-object-detection-2 in yolov11:: 100%|██████████| 1218/1218 [00:00<00:00, 7578.70it/s]

# %%
# !ffmpeg -i {"/content/praktik-object-detection-2/telur_video.mp4"} -vcodec libx264 {"finish.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/praktik-object-detection-2/telur_video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2025-05-19T00:29:10.000000Z
#     location        : +00.0000+000.0000/
#     location-eng    : +00.0000+000.0000/
#     com.android.version: 15
#   Duration: 00:00:39.36, start: 0.000000, bitrate: 21469 kb/s
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2025-05-19T00:29:10.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Video: hevc (Main) (hvc1 / 0x31637668), yuvj420p(pc, bt470bg/bt470bg/smpte170m), 1080x1920, 21213 kb/s, 29.60 fps, 30 tbr, 90k tbn, 90k tbc (default)
#     Metadata:
#       creation_time   : 2025-05-19T00:29:10.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (hevc (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x57aaf82de380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x57aaf82de380] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x57aaf82de380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'finish.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     com.android.version: 15
#     location        : +00.0000+000.0000/
#     location-eng    : +00.0000+000.0000/
#     encoder         : Lavf58.76.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt470bg/bt470bg/smpte170m, progressive), 1080x1920, q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2025-05-19T00:29:10.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2025-05-19T00:29:10.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame= 1181 fps=5.0 q=-1.0 Lsize=   46916kB time=00:00:39.26 bitrate=9787.9kbits/s dup=16 drop=0 speed=0.168x
# video:46271kB audio:602kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.092531%
# [libx264 @ 0x57aaf82de380] frame I:10    Avg QP:23.39  size:196730
# [libx264 @ 0x57aaf82de380] frame P:305   Avg QP:26.43  size: 86123
# [libx264 @ 0x57aaf82de380] frame B:866   Avg QP:29.05  size: 22109
# [libx264 @ 0x57aaf82de380] consecutive B-frames:  1.2%  1.9%  3.8% 93.1%
# [libx264 @ 0x57aaf82de380] mb I  I16..4:  6.0% 76.1% 18.0%
# [libx264 @ 0x57aaf82de380] mb P  I16..4:  1.6% 16.0%  1.9%  P16..4: 44.3% 20.1% 10.0%  0.0%  0.0%    skip: 6.1%
# [libx264 @ 0x57aaf82de380] mb B  I16..4:  0.1%  1.1%  0.1%  B16..8: 49.6%  5.1%  1.0%  direct: 5.8%  skip:37.3%  L0:47.3% L1:45.0% BI: 7.7%
# [libx264 @ 0x57aaf82de380] 8x8 transform intra:81.9% inter:74.7%
# [libx264 @ 0x57aaf82de380] coded y,uvDC,uvAC intra: 81.1% 49.0% 3.5% inter: 31.9% 15.1% 0.0%
# [libx264 @ 0x57aaf82de380] i16 v,h,dc,p:  7%  9%  2% 82%
# [libx264 @ 0x57aaf82de380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 16% 12%  9% 10% 10% 10% 10% 10%
# [libx264 @ 0x57aaf82de380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 19% 11%  7% 14% 10% 11%  7%  7%
# [libx264 @ 0x57aaf82de380] i8c dc,h,v,p: 60% 16% 16%  8%
# [libx264 @ 0x57aaf82de380] Weighted P-Frames: Y:4.9% UV:2.3%
# [libx264 @ 0x57aaf82de380] ref P L0: 49.7% 16.0% 27.5%  6.5%  0.3%
# [libx264 @ 0x57aaf82de380] ref B L0: 92.7%  6.0%  1.3%
# [libx264 @ 0x57aaf82de380] ref B L1: 98.3%  1.7%
# [libx264 @ 0x57aaf82de380] kb/s:9628.65
# [aac @ 0x57aaf82daa80] Qavg: 1228.727

# %%
cap = cv2.VideoCapture("/content/praktik-object-detection-2/telur_video.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH,
                                       cv2.CAP_PROP_FRAME_HEIGHT,
                                       cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("counting.avi",
                               cv2.VideoWriter_fourcc(*"mp4v"),
                               fps, (w, h))

# %% [markdown]
# ### Define Region Coordinates
#
# Here, we set the coordinates for specific regions to ensure accurate object tracking and analysis within the video or stream. This helps monitor and count objects effectively in different areas.

# %%
# Define region points
# region_points = [(20, 400), (1080, 400)]  # For line counting
region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]  # For rectangle region counting
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]  # For polygon region counting

# %% [markdown]
# ### Initialize the ObjectCounter Class
#
# - Now, let's initialize the `ObjectCounter` class to track and count objects in each frame of the video.

# %%
# Init ObjectCounter
counter = solutions.ObjectCounter(
    show=True,  # Display the output
    region=region_points,  # Pass region points
    model="/content/praktik-object-detection-2/telur_model.pt",  # model="yolo11n-obb.pt" for object counting using YOLO11 OBB model.
    line_width=5,
    # classes=[0, 2],  # If you want to count specific classes i.e person and car with COCO pretrained model.
    # show_in=True,  # Display in counts
    # show_out=True,  # Display out counts
)
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': '/content/praktik-object-detection-2/telur_model.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': [(20, 400), (1080, 400), (1080, 360), (20, 360)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 5, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}

# %% [markdown]
# ### Process Video Frames
#
# In this step, we will process each frame of the video to detect and analyze objects. This allows for real-time tracking and counting, based on the visual data in the frames.

# %%
# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    results = counter(im0)  # count the objects
    video_writer.write(results.plot_im)   # write the video frames

cap.release()   # Release the capture
video_writer.release()
cv2.destroyAllWindows()
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 0.5s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# 0: 640x384 2 telur kampungs, 56.7ms
# Speed: 7.2ms preprocess, 56.7ms inference, 367.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 16.2ms
# Speed: 5.6ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 19.3ms
# Speed: 6.4ms preprocess, 19.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 19.6ms
# Speed: 9.2ms preprocess, 19.6ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 18.7ms
# Speed: 3.2ms preprocess, 18.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 14.5ms
# Speed: 3.3ms preprocess, 14.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 13.7ms
# Speed: 3.5ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 21.1ms
# Speed: 6.6ms preprocess, 21.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 24.2ms
# Speed: 3.8ms preprocess, 24.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 26.5ms
# Speed: 5.5ms preprocess, 26.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 23.7ms
# Speed: 5.3ms preprocess, 23.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 25.8ms
# Speed: 6.4ms preprocess, 25.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 23.9ms
# Speed: 4.0ms preprocess, 23.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.9ms
# Speed: 4.1ms preprocess, 14.9ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 16.2ms
# Speed: 3.6ms preprocess, 16.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 17.0ms
# Speed: 3.4ms preprocess, 17.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 23.1ms
# Speed: 3.4ms preprocess, 23.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 23.9ms
# Speed: 10.8ms preprocess, 23.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 22.4ms
# Speed: 4.0ms preprocess, 22.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 14.0ms
# Speed: 3.4ms preprocess, 14.0ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 31.9ms
# Speed: 6.4ms preprocess, 31.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 18.2ms
# Speed: 10.7ms preprocess, 18.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 18.0ms
# Speed: 3.9ms preprocess, 18.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 16.5ms
# Speed: 3.8ms preprocess, 16.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.0ms
# Speed: 4.6ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 16.3ms
# Speed: 3.4ms preprocess, 16.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 17.9ms
# Speed: 4.3ms preprocess, 17.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 17.3ms
# Speed: 4.8ms preprocess, 17.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 17.7ms
# Speed: 4.3ms preprocess, 17.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 17.5ms
# Speed: 4.3ms preprocess, 17.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 14.9ms
# Speed: 3.3ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 14.7ms
# Speed: 3.4ms preprocess, 14.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 22.0ms
# Speed: 3.4ms preprocess, 22.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 17.1ms
# Speed: 4.2ms preprocess, 17.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 17.5ms
# Speed: 3.7ms preprocess, 17.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 16.6ms
# Speed: 4.8ms preprocess, 16.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 (no detections), 16.5ms
# Speed: 4.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 640x384 (no detections), 15.1ms
# Speed: 3.7ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 640x384 (no detections), 14.1ms
# Speed: 3.8ms preprocess, 14.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 640x384 1 telur kampung, 15.1ms
# Speed: 6.2ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 (no detections), 15.4ms
# Speed: 3.7ms preprocess, 15.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 640x384 2 telur kampungs, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 15.9ms
# Speed: 3.6ms preprocess, 15.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.4ms
# Speed: 3.6ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 15.2ms
# Speed: 3.9ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.6ms
# Speed: 5.0ms preprocess, 14.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.6ms
# Speed: 3.5ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 19.3ms
# Speed: 3.4ms preprocess, 19.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 18.6ms
# Speed: 3.7ms preprocess, 18.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.7ms
# Speed: 3.4ms preprocess, 14.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 16.9ms
# Speed: 4.0ms preprocess, 16.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 16.4ms
# Speed: 3.6ms preprocess, 16.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 15.4ms
# Speed: 3.8ms preprocess, 15.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 17.9ms
# Speed: 4.5ms preprocess, 17.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 15.4ms
# Speed: 3.4ms preprocess, 15.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 14.7ms
# Speed: 3.4ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 14.9ms
# Speed: 3.4ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 17.9ms
# Speed: 3.5ms preprocess, 17.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 33.7ms
# Speed: 3.5ms preprocess, 33.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 26.9ms
# Speed: 5.2ms preprocess, 26.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 17.0ms
# Speed: 3.7ms preprocess, 17.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 15.9ms
# Speed: 3.8ms preprocess, 15.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 15.0ms
# Speed: 3.5ms preprocess, 15.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 20.9ms
# Speed: 3.8ms preprocess, 20.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 15.3ms
# Speed: 3.4ms preprocess, 15.3ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 17.7ms
# Speed: 4.0ms preprocess, 17.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 14.5ms
# Speed: 3.4ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs,
ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 640x384 1 telur kampung, 1 telur puyuh, 16.9ms
# Speed: 3.5ms preprocess, 16.9ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 1 telur puyuh, 15.5ms
# Speed: 4.7ms preprocess, 15.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 640x384 2 telur kampungs, 14.1ms
# Speed: 3.7ms preprocess, 14.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 15.4ms
# Speed: 3.9ms preprocess, 15.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 19.4ms
# Speed: 3.5ms preprocess, 19.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.5ms
# Speed: 3.8ms preprocess, 14.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 16.0ms
# Speed: 3.4ms preprocess, 16.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 15.7ms
# Speed: 3.5ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 1 telur puyuh, 14.5ms
# Speed: 3.5ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 640x384 2 telur kampungs, 14.2ms
# Speed: 4.1ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.8ms
# Speed: 3.8ms preprocess, 14.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.7ms
# Speed: 3.5ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.3ms
# Speed: 3.5ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 14.2ms
# Speed: 3.5ms preprocess, 14.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 (no detections), 13.9ms
# Speed: 3.1ms preprocess, 13.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 640x384 1 telur kampung, 14.0ms
# Speed: 3.2ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 21.4ms
# Speed: 4.2ms preprocess, 21.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 14.1ms
# Speed: 3.1ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 16.2ms
# Speed: 3.6ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 14.6ms
# Speed: 3.9ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 15.1ms
# Speed: 3.5ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 14.7ms
# Speed: 3.6ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 14.4ms
# Speed: 3.8ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 40.3ms
# Speed: 6.5ms preprocess, 40.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 2 telur kampungs, 13.6ms
# Speed: 4.1ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 2 telur kampungs, 1 telur puyuh, 13.8ms
# Speed: 7.0ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 640x384 2 telur kampungs, 1 telur puyuh, 14.9ms
# Speed: 3.6ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 640x384 1 telur kampung, 1 telur puyuh, 14.2ms
# Speed: 3.7ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur puyuh, 14.0ms
# Speed: 3.8ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 14.1ms
# Speed: 4.5ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 14.7ms
# Speed: 4.2ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 14.7ms
# Speed: 3.5ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 (no detections), 14.1ms
# Speed: 3.7ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 640x384 (no detections), 14.4ms
# Speed: 4.2ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 640x384 1 telur kampung, 37.6ms
# Speed: 3.9ms preprocess, 37.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 14.2ms
# Speed: 3.7ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 (no detections), 14.3ms
# Speed: 8.5ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# WARNING ⚠️ no tracks found!
# 🚀 Results: SolutionResults()
#
# 0: 640x384 2 telur kampungs, 15.0ms
# Speed: 4.4ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 640x384 1 telur kampung, 15.5ms
# Speed: 3.5ms preprocess, 15.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 13.7ms
# Speed: 3.4ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 18.3ms
# Speed: 3.4ms preprocess, 18.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 13.6ms
# Speed: 3.6ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 13.7ms
# Speed: 3.6ms preprocess, 13.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 640x384 1 telur kampung, 17.8ms
# ...
#
# 0: 640x384 18 telurayam rass, 19.4ms
# Speed: 3.4ms preprocess, 19.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=5, out_count=12, classwise_count={'telurayam ras': {'IN': 4, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=18)
#
# 0: 640x384 16 telurayam rass, 14.5ms
# Speed: 3.6ms preprocess, 14.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=5, out_count=12, classwise_count={'telurayam ras': {'IN': 4, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 16 telurayam rass, 21.3ms
# Speed: 3.7ms preprocess, 21.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=5, out_count=12, classwise_count={'telurayam ras': {'IN': 4, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 14 telurayam rass, 18.5ms
# Speed: 7.0ms preprocess, 18.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=5, out_count=12, classwise_count={'telurayam ras': {'IN': 4, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=14)
#
# 0: 640x384 15 telurayam rass, 15.1ms
# Speed: 3.7ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=15)
#
# 0: 640x384 15 telurayam rass, 14.4ms
# Speed: 3.6ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=15)
#
# 0: 640x384 17 telurayam rass, 15.0ms
# Speed: 3.7ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 20 telurayam rass, 20.6ms
# Speed: 3.8ms preprocess, 20.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=20)
#
# 0: 640x384 17 telurayam rass, 14.8ms
# Speed: 3.5ms preprocess, 14.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 18 telurayam rass, 17.1ms
# Speed: 3.5ms preprocess, 17.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=18)
#
# 0: 640x384 19 telurayam rass, 13.2ms
# Speed: 3.5ms preprocess, 13.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=19)
#
# 0: 640x384 18 telurayam rass, 16.9ms
# Speed: 3.5ms preprocess, 16.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=18)
#
# 0: 640x384 16 telurayam rass, 14.2ms
# Speed: 3.6ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 17 telurayam rass, 14.0ms
# Speed: 3.4ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 16 telurayam rass, 14.4ms
# Speed: 3.6ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 17 telurayam rass, 15.5ms
# Speed: 3.7ms preprocess, 15.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 17 telurayam rass, 16.8ms
# Speed: 3.7ms preprocess, 16.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 14 telurayam rass, 15.0ms
# Speed: 3.5ms preprocess, 15.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=14)
#
# 0: 640x384 14 telurayam rass, 19.4ms
# Speed: 4.6ms preprocess, 19.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=14)
#
# 0: 640x384 15 telurayam rass, 14.1ms
# Speed: 3.6ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=15)
#
# 0: 640x384 13 telurayam rass, 22.7ms
# Speed: 3.9ms preprocess, 22.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=13)
#
# 0: 640x384 13 telurayam rass, 17.2ms
# Speed: 7.2ms preprocess, 17.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=12, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 7}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=13)
#
# 0: 640x384 14 telurayam rass, 24.7ms
# Speed: 3.5ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=13, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 8}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=14)
#
# 0: 640x384 17 telurayam rass, 14.0ms
# Speed: 3.9ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=13, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 8}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 17 telurayam rass, 13.9ms
# Speed: 3.2ms preprocess, 13.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 19 telurayam rass, 14.5ms
# Speed: 3.6ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=19)
#
# 0: 640x384 18 telurayam rass, 28.0ms
# Speed: 3.7ms preprocess, 28.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=18)
#
# 0: 640x384 17 telurayam rass, 14.1ms
# Speed: 3.6ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 16 telurayam rass, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 14 telurayam rass, 20.6ms
# Speed: 3.5ms preprocess, 20.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=14)
#
# 0: 640x384 14 telurayam rass, 15.1ms
# Speed: 3.4ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=14)
#
# 0: 640x384 17 telurayam rass, 14.2ms
# Speed: 3.6ms preprocess, 14.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 15 telurayam rass, 14.2ms
# Speed: 4.5ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=15)
#
# 0: 640x384 14 telurayam rass, 14.4ms
# Speed: 3.8ms preprocess, 14.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=14)
#
# 0: 640x384 14 telurayam rass, 14.0ms
# Speed: 3.6ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=14)
#
# 0: 640x384 12 telurayam rass, 13.9ms
# Speed: 3.5ms preprocess, 13.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=12)
#
# 0: 640x384 12 telurayam rass, 14.4ms
# Speed: 3.7ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=12)
#
# 0: 640x384 15 telurayam rass, 16.1ms
# Speed: 5.5ms preprocess, 16.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=15)
#
# 0: 640x384 15 telurayam rass, 14.0ms
# Speed: 3.6ms preprocess, 14.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=15)
#
# 0: 640x384 16 telurayam rass, 13.9ms
# Speed: 3.5ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 16 telurayam rass, 14.4ms
# Speed: 3.3ms preprocess, 14.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 17 telurayam rass, 21.9ms
# Speed: 8.5ms preprocess, 21.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 16 telurayam rass, 16.7ms
# Speed: 10.2ms preprocess, 16.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 16 telurayam rass, 13.9ms
# Speed: 3.3ms preprocess, 13.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 17 telurayam rass, 14.4ms
# Speed: 3.5ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 16 telurayam rass, 20.5ms
# Speed: 4.9ms preprocess, 20.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 17 telurayam rass, 21.0ms
# Speed: 3.5ms preprocess, 21.0ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 17 telurayam rass, 15.9ms
# Speed: 3.5ms preprocess, 15.9ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 17 telurayam rass, 15.1ms
# Speed: 3.3ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 16 telurayam rass, 29.0ms
# Speed: 3.4ms preprocess, 29.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 17 telurayam rass, 14.4ms
# Speed: 4.0ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=17)
#
# 0: 640x384 16 telurayam rass, 17.2ms
# Speed: 4.7ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
#
# 0: 640x384 16 telurayam rass, 13.6ms
# Speed: 3.5ms preprocess, 13.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(in_count=6, out_count=14, classwise_count={'telurayam ras': {'IN': 5, 'OUT': 9}, 'telur kampung': {'IN': 1, 'OUT': 5}}, total_tracks=16)
# Video frame is empty or video processing has been successfully completed.

# %%
# %pip install --upgrade ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.141)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %% [markdown]
# Crafted with 💙 by [Ultralytics](https://ultralytics.com/)
#
# 🌟 Explore and star the [Ultralytics Notebooks](https://github.com/ultralytics/notebooks/) to supercharge your AI journey! 🚀
